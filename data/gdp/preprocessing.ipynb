# %%
import pandas as pd
import country_converter as coco

# %%
gdp = pd.read_excel('gdp.xls')
gdp
# Out:
#     GDP, current prices (Billions of U.S. dollars)       1980       1981  \
# 0                                              NaN        NaN        NaN
# 1                                      Afghanistan    no data    no data
# 2                                          Albania      1.946      2.229
# 3                                          Algeria     42.346     44.372
# 4                                          Andorra    no data    no data
# ..                                             ...        ...        ...
# 226                       Other advanced economies    774.168    789.571
# 227                             Sub-Saharan Africa    325.349    342.175
# 228                                          World  11245.344  11497.911
# 229                                            NaN        NaN        NaN
# 230                                     ©IMF, 2021        NaN        NaN
#
#           1982       1983       1984       1985      1986       1987  \
# ...

# %%
gdp.dropna(inplace=True)

# %%
gdp
# Out:
#     GDP, current prices (Billions of U.S. dollars)       1980       1981  \
# 1                                      Afghanistan    no data    no data
# 2                                          Albania      1.946      2.229
# 3                                          Algeria     42.346     44.372
# 4                                          Andorra    no data    no data
# 5                                           Angola      6.639      6.214
# ..                                             ...        ...        ...
# 224                  Major advanced economies (G7)   6902.247   7116.652
# 225                   Middle East and Central Asia    555.411    584.579
# 226                       Other advanced economies    774.168    789.571
# 227                             Sub-Saharan Africa    325.349    342.175
# 228                                          World  11245.344  11497.911
#
#           1982       1983       1984       1985       1986       1987  \
# ...

# %%
gdp.rename(columns={'GDP, current prices (Billions of U.S. dollars)': 'country'}, inplace=True)

# %%
gdp
# Out:
#                            country       1980       1981       1982  \
# 1                      Afghanistan    no data    no data    no data
# 2                          Albania      1.946      2.229      2.296
# 3                          Algeria     42.346     44.372      44.78
# 4                          Andorra    no data    no data    no data
# 5                           Angola      6.639      6.214      6.214
# ..                             ...        ...        ...        ...
# 224  Major advanced economies (G7)   6902.247   7116.652    7085.18
# 225   Middle East and Central Asia    555.411    584.579    568.983
# 226       Other advanced economies    774.168    789.571    784.101
# 227             Sub-Saharan Africa    325.349    342.175    344.274
# 228                          World  11245.344  11497.911  11277.191
#
#           1983       1984       1985       1986       1987       1988  ...  \
# ...

# %%
gdp_melted = gdp.melt(id_vars=['country'], value_vars=[col for col in gdp.columns if col != 'country'], value_name='gdp', var_name='year')

# %%
gdp_melted = gdp_melted[(gdp_melted['year'] >= 2018) & (gdp_melted['year'] <= 2023)]
gdp_melted
# Out:
#                              country  year         gdp
# 8664                     Afghanistan  2018      18.401
# 8665                         Albania  2018      15.147
# 8666                         Algeria  2018     175.367
# 8667                         Andorra  2018       3.217
# 8668                          Angola  2018     101.353
# ...                              ...   ...         ...
# 10027  Major advanced economies (G7)  2023   47987.355
# 10028   Middle East and Central Asia  2023    5125.661
# 10029       Other advanced economies  2023    9365.788
# 10030             Sub-Saharan Africa  2023    2237.221
# 10031                          World  2023  108582.123
#
# [1368 rows x 3 columns]

# %%
cc = coco.CountryConverter()
gdp_melted['country'] = gdp_melted['country'].apply(lambda x: cc.convert(x, to='name_short'))
# Out:
# Africa (Region) not found in regex
# Asia and Pacific not found in regex
# More then one regular expression match for Australia and New Zealand
# More then one regular expression match for Australia and New Zealand
# More then one regular expression match for Australia and New Zealand
# More then one regular expression match for Australia and New Zealand
# More then one regular expression match for Australia and New Zealand
# More then one regular expression match for Australia and New Zealand
# More then one regular expression match for Australia and New Zealand
# More then one regular expression match for Australia and New Zealand
# More then one regular expression match for Australia and New Zealand
# More then one regular expression match for Australia and New Zealand
# More then one regular expression match for Australia and New Zealand
# More then one regular expression match for Australia and New Zealand
# More then one regular expression match for Australia and New Zealand
# ...

# %%
gdp_melted[gdp_melted['country'] == 'United States']
# Out:
#             country  year        gdp
# 8850  United States  2018   20527.15
# 9078  United States  2019    21372.6
# 9306  United States  2020   20893.75
# 9534  United States  2021   22939.58
# 9762  United States  2022  24796.076
# 9990  United States  2023  25938.159

# %%
gdp_melted.to_csv('gdp.csv')
